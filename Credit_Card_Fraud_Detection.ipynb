# %% [markdown]
# <a href="https://colab.research.google.com/github/MessaoudiOussama/Credit-Card-Fraud-Detection/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing the Dataset

# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-381ddce2-25b5-438f-b14b-5d238d8c907d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-381ddce2-25b5-438f-b14b-5d238d8c907d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download mlg-ulb/creditcardfraud
# Out:
# ...
# 100% 66.0M/66.0M [00:03<00:00, 29.1MB/s]
# 100% 66.0M/66.0M [00:03<00:00, 20.4MB/s]

# %%
# !unzip /content/creditcardfraud.zip
# Out:
# Archive:  /content/creditcardfraud.zip
#   inflating: creditcard.csv

# %% [markdown]
# ## Python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Data Exploration

# %%
df = pd.read_csv("/content/creditcard.csv")
print(df.shape)
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# No null values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
features = ['V1', 'V2', 'V3', 'V10', 'V24', 'Amount']

plt.figure(figsize=(20,12))
for i in range(len(features)):
  plt.subplot(3,3,i+1)
  plt.hist(df[features[i]])
  plt.ylabel('Count')
  plt.xlabel(features[i])

plt.show()

# %% [markdown]
# ## Data Imbalance

# %% [markdown]
# We notice a great imbalance between the two classes

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
print("Normal transactions percentage: ", round(df['Class'].value_counts()[0] / len(df) * 100, 2), "%")
print("Fraudulent transactions percentage: ", round(df['Class'].value_counts()[1] / len(df) * 100, 2), "%")
# Out:
# Normal transactions percentage:  99.83 %
# Fraudulent transactions percentage:  0.17 %

# %% [markdown]
# Clearly this dataset is highy imbalanced and there are many ways to approach this problem:
#
#
# *   Collecting more data
# *   Resamplin the dataset
#   *   Over-sampling
#   *   Down-sampling
# *   Adjusting the performance metrics

# %% [markdown]
# Working with the original dataset as imbalanced as it is may lead to serious problems, for example we might have an overfitting for the normal transaction side, and the model might assume that the instance is highly probable to be a normal transaction.

# %% [markdown]
# We choose to do a down-sampling to having a 50/50 ratio of fraud and non-fraud transactions.

# %% [markdown]
# ## Feature Scaling By Density

# %%
var = df.columns.values

normal = df.loc[df['Class'] == 0]
fraud = df.loc[df['Class'] == 1]

sns.set_style("whitegrid")
plt.figure()
fig, ax = plt.subplots(8, 4, figsize=(16, 28))

i = 0
for feature in var:
  i += 1
  plt.subplot(8, 4, i)
  sns.kdeplot(normal[feature], label="Normal")
  sns.kdeplot(fraud[feature], label="Fraud")
  plt.xlabel(feature, fontsize=12)

plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.

# %% [markdown]
# We can clearly see that all the VX variables are ceneterd around 0, for the normal distribution which leads us to be believe that they are already scaled. The little skewness of the fraudulent transactions distibution might be justified by the imbalance of the dataset towards the normal distribution.

# %% [markdown]
# The rest of the variables are: Time and Amount, which seem not to be scaled as the other variables. This is why the next step is going to be the scaling of both variables.
